# %% [markdown]
# In this exercise you'll try to build a neural network that predicts the price of
# a house according to a simple formula.
#
# So, imagine if house pricing was as easy as a house costs 50k + 50k per bedroom,
# so that a 1 bedroom house costs 100k, a 2 bedroom house costs 150k etc.
#
# How would you create a neural network that learns this relationship so that it
# would predict a 7 bedroom house as costing close to 400k etc.
#
# Hint: Your network might work better if you scale the house price down. You
# don't have to give the answer 400...it might be better to create something that
# predicts the number 4, and then your answer is in the 'hundreds of thousands'
# etc.

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
# GRADED FUNCTION: house_model
def house_model(y_new):

    xs = np.array([n for n in range(1, 11)])
    ys = np.array([0.5 * (n + 1) for n in range(1, 11)])

    model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
    model.compile(loss="mean_squared_error", optimizer="sgd")
    model.fit(xs, ys, epochs=700)

    return model.predict(y_new)[0]

# %%
prediction = house_model([7.0])
print(prediction)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0712 07:17:23.193017 140201393882944 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Epoch 1/700
# 10/10 [==============================] - 3s 327ms/sample - loss: 47.6118
# Epoch 2/700
# 10/10 [==============================] - 0s 464us/sample - loss: 2.2084
# Epoch 3/700
# 10/10 [==============================] - 0s 236us/sample - loss: 0.1250
# Epoch 4/700
# 10/10 [==============================] - 0s 242us/sample - loss: 0.0293
# Epoch 5/700
# 10/10 [==============================] - 0s 135us/sample - loss: 0.0247
# Epoch 6/700
# 10/10 [==============================] - 0s 206us/sample - loss: 0.0243
# ...

# %%
# Now click the "Submit Assignment" button above.
# Once that is complete, please run the following two cells to save your work and close the notebook.

# %%
# %%javascript
# <!-- Save the notebook -->
# IPython.notebook.save_checkpoint();

# %%
# %%javascript
# IPython.notebook.session.delete();
# window.onbeforeunload = null
# setTimeout(function() { window.close(); }, 1000);
